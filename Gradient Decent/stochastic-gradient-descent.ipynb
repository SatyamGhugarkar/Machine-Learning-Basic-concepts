# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)

# SGD = Gradient Descent
reg = SGDRegressor(max_iter=100,learning_rate='constant', eta0=0.01)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("Coefficients:", reg.coef_)
print("Intercept:", reg.intercept_)
# Out:
# R2 Score: 0.4330135091255157
# Coefficients: [  56.00078036  -66.10888268  347.63599991  245.98826412   18.02886352
#   -27.36690755 -172.7789696   128.91357622  316.28746158  128.39596935]
# Intercept: [152.77865061]
# C:\Users\ASUS\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_stochastic_gradient.py:1612: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
